# %%
#imports
from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib

# %%
#connect website
URL = 'https://www.amazon.in/iPhone-17-Pro-Max-Promotion/dp/B0FQF331K6/ref=sr_1_1_sspa?crid=XU6UK4OX5C8G&dib=eyJ2IjoiMSJ9.e-ME5w9S8o4zhdbDZdGRllFT7qPOnA-QULiyobZuovnJj6ec976ckVKXwcaRLQi7qEHAlZisuovAKCpM2mkewfZv7rhtzRnWNT-eqQhP5OD81vBmACxxiZpPf2EgSCuIcOnQQDpfvPgZG2piFwD11c2djrqAO-kCJb8l5NCG7Cg4nmHUCh1ml0C3jtEnlWwWuQ0lF5ruEHQNY-WK_Tk9UXrqD0Fe3E28FxOZa3IfHp8.TUzTMaWXdxPVRnN9LiI5y2ZxsWnT5BGp27MHFLQbDBM&dib_tag=se&keywords=phone&qid=1773497444&sprefix=phone%2Caps%2C491&sr=8-1-spons&aref=UjzBsoTArb&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1'

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content,"html.parser")

title = soup2.find(id='productTitle').get_text()

price = soup2.find(id='apex-pricetopay-accessibility-label').get_text()

print(title)
print(price)

# %%
title = title.replace("\n","").strip()
price = price.strip()

print(title)
print(price)

# %%
import datetime

day = datetime.date.today()
time = datetime.datetime.now().strftime("%H:%M:%S")
print(day)
print(time)

# %%
import csv
header = ['Time Stamp','Product Title','Price']
data = [day,title,price,time]

with open('AmazonWebScraper.csv','w', newline = '', encoding ='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\user\Desktop\jupyter\AmazonWebScraper.csv')
print(df)

# %%
with open('AmazonWebScraper.csv','a+', newline = '', encoding ='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
def check_price():
    URL = 'https://www.amazon.in/iPhone-17-Pro-Max-Promotion/dp/B0FQF331K6/ref=sr_1_1_sspa?crid=XU6UK4OX5C8G&dib=eyJ2IjoiMSJ9.e-ME5w9S8o4zhdbDZdGRllFT7qPOnA-QULiyobZuovnJj6ec976ckVKXwcaRLQi7qEHAlZisuovAKCpM2mkewfZv7rhtzRnWNT-eqQhP5OD81vBmACxxiZpPf2EgSCuIcOnQQDpfvPgZG2piFwD11c2djrqAO-kCJb8l5NCG7Cg4nmHUCh1ml0C3jtEnlWwWuQ0lF5ruEHQNY-WK_Tk9UXrqD0Fe3E28FxOZa3IfHp8.TUzTMaWXdxPVRnN9LiI5y2ZxsWnT5BGp27MHFLQbDBM&dib_tag=se&keywords=phone&qid=1773497444&sprefix=phone%2Caps%2C491&sr=8-1-spons&aref=UjzBsoTArb&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1'

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content,"html.parser")

title = soup2.find(id='productTitle').get_text()

price = soup2.find(id='apex-pricetopay-accessibility-label').get_text()

title = title.replace("\n","").strip()
price = price.strip()

import datetime

day = datetime.date.today()

with open('AmazonWebScraper.csv','a+', newline = '', encoding ='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

#if price<100000:
#    send_mail()

# %%
while (True):
    check_price()
    time.sleep(86400)

# %%
import pandas
df = pd.read.csv(r'C:\Users\user\Desktop\jupyter\AmazonWebScraper.csv')
print(df)

# %%
# If uou want to try sending yourself an email (just for fun) when a price hits below a certain level you can try it
# out with this script

#def send_mail():
#    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
#    server.starttls()
#    server.ehlo()
#    server.login('AlexTheAnalyst95@gmail.com','xxxxxxxxxxxxxx')
    
#    subject = "The Shirt you want is below $15! Now is your chance to buy!"
#    body = "Alex, This is the moment we have been waiting for. Now is your chance to pick up the shirt of your dreams. Don't mess it up! Link here: https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data+analyst+tshirt&qid=1626655184&sr=8-3"
   
#    msg = f"Subject: {subject}\n\n{body}"
    
#    server.sendmail(
#        'AlexTheAnalyst95@gmail.com',
#        msg
     
    )
